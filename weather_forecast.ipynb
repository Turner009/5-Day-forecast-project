# %% [markdown]
# # API Scavenger Hunt! 👀
#
# ## Introduction 👋
# In this lab, you will learn the fundamentals of working with APIs as a data analyst by making `requests` to an API and formatting the `response` data appropriately. Each task will offer a different challenge, such as:
#
# - working with different request parameters and query parameters,
# - using API keys and tokens, and
# - eventually signing up for and making requests from the Open Weather Map API, then exporting data from that request to JSON and importing the JSON into Tableau.
#
# ## Resources 📕
# We recommend having the following Student Hub articles open while making your requests
# - [RESTful APIs](https://devcodecamp.helpkit.so/definitions-examples-and-frequently-asked-questions/vUgiURdNAgva1AaaH99uBY/rest-apis/oN6ZdGaNop8f52gx43kTj6)
# - [Importing & Exporting JSON with Pandas](https://devcodecamp.helpkit.so/definitions-examples-and-frequently-asked-questions/vUgiURdNAgva1AaaH99uBY/importing--exporting-data-with-pandas/3gXNpDMk4fkWP6zdepRCod#json-files)

# %% [markdown]
# ---
# ## Task 0: Imports
# ---
# - ✅ In the code block below, import the `requests`, `pandas`, and `json` packages
#     - > 👉🏼 The imports should be written as three different lines. Don't forget the alias for Pandas!

# %%
import pandas as pd
import requests
import json
from datetime import datetime

# %% [markdown]
# ---
# ## Task 1: Current Forecast
# ---
# The Open Weather Map API is a popular, open source API for weather forecasts that includes future weather, historical weather data, pollution and air quality forecasting, and more!
#
# For the purpose of this lab, we will focus on two main features of Open Weather Map API:
# - Current Weather Data
# - 5 Day / 3 Hour Forecast Data
#
# We'll use this API to get practice with basic API usage and documentation parsing.
#
# ### Subtask 1: Create Open Weather Map API Account & Obtain Key
# - ✅ Navigate to the following website and locate the `Sign In` page: 👉🏼 [Open Weather Map API](https://openweathermap.org/) 👈🏻
#     - Click the option to **Create a new account**
# - ✅ After creating your account, check your email for a verification message from Open Weather Map API
# - ✅ Locate the API Key (Select your username in the top right --> My API Keys) and set it equal to a variable called `key` in the code block below. (Make sure it is a string!)

# %%
key = "753349528c59f4ab817f5b15471449ce"

# %% [markdown]
# ### Subtask 2: Calculate Latitude & Longitude of Your Location
# - ✅ Navigate to the following website: 👉🏼 [GPS Coordinates](https://www.gps-coordinates.net/my-location) 👈🏻
# - ✅ When prompted, allow the browser to access your current location
# - ✅ Note the values for Latitude and Longitude, and set them equal to the variables called `lat` and `lon` in the code block below. (Make sure it is a number!)

# %%
lat = 41.700557
lon = -87.533158

# %% [markdown]
# ### Subtask 3: Generate Request URL
# TODO
# - ✅ Navigate to the following website  👉🏼 [API Documentation](https://openweathermap.org/api) 👈🏻
# - ✅ Locate the documentation for the **Current Weather Data** API
# - ✅ Copy the URL for this API, and store it in the `url` variable below.  Use a **Python f string** to insert your latitude, longitude, and API key values into the URL

# %%
url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={key}"

# %% [markdown]
# ### Subtask 4: GET your current weather forecast.
# TODO
# - ✅ Use the above URL to make a GET request, and save the result as a variable
# - ✅ "Prettify" the response & print it out, then open the output in a text editor for easy reference.
#     - > Use that output to answer the questions in the Markdown block below

# %%
current_weather = requests.get(url).json()
pretty_weather = json.dumps(current_weather, indent=4, skipkeys=True)
print(pretty_weather)
# Out:
# {
#     "coord": {
#         "lon": -87.5332,
#         "lat": 41.7006
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 294.67,
#         "feels_like": 293.5,
#         "temp_min": 293.73,
#         "temp_max": 295.47,
#         "pressure": 1026,
#         "humidity": 24
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.14,
#         "deg": 210
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1681166905,
#     "sys": {
#         "type": 1,
#         "id": 4309,
#         "country": "US",
#         "sunrise": 1681125494,
#         "sunset": 1681172657
#     },
#     "timezone": -18000,
#     "id": 4928208,
#     "name": "Whiting",
#     "cod": 200
# }

# %% [markdown]
# QUESTION 1
# - ❓ What is the **wind speed** for your current location?
# - 🅰️:0
#
# QUESTION 2
# - ❓ How would you access the value for **wind speed** within this response?
# - 🅰️: `wind_speed = current_weather['wind']['speed'] `
#
# QUESTION 3
# - ❓ What is the **weather description** for your current location?
# - 🅰️: clear sky
#
# QUESTION 4
# - ❓ How would you access the value for **weather description** within this response?
# - 🅰️: `weather_description =  current_weather['weather'][0]['description'] `

# %% [markdown]
# ---
# ## Task 2: 5 Day / 3 Hour Forecast
# ---
#
# ### Subtask 1: Find the Forecast URL
# Todo
# - ✅ Navigate to the following website  👉🏼 [API Documentation](https://openweathermap.org/api) 👈🏻
# - ✅ Locate the documentation for the **5 Day / 3 Hour Forecast** API
# - ✅ Copy the URL for this API, and store it in the `forecast_url` variable below.  Use a **Python f string** to insert your latitude, longitude, and API key values into the URL
# - ✅ Add the following additional parameter to the **end** of `forecast_url`, to convert temperature to Fahrenheit
#     - > **`&units=imperial`**

# %%
forecast_url = f"https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={key}&units=imperial"

# %% [markdown]
# ### Subtask 2: GET your 5-day weather forecast.
# TODO
# - ✅ Use the above URL to make a GET request, and save the result as a variable
# - ✅ "Prettify" the response & print it out, then open the output in a text editor for easy reference.

# %%
five_day_weather = requests.get(forecast_url).json()
pretty_fd_weather = json.dumps(five_day_weather, indent=4, skipkeys=True)
print(pretty_fd_weather)
# Out:
# {
#     "cod": "200",
#     "message": 0,
#     "cnt": 40,
#     "list": [
#         {
#             "dt": 1681171200,
#             "main": {
#                 "temp": 70.74,
#                 "feels_like": 68.63,
#                 "temp_min": 62.11,
#                 "temp_max": 70.74,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 1004,
#                 "humidity": 24,
#                 "temp_kf": 4.79
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 6.33,
#                 "deg": 221,
#                 "gust": 10.83
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-11 00:00:00"
#         },
#         {
#             "dt": 1681182000,
#             "main": {
#                 "temp": 66.06,
#                 "feels_like": 63.91,
#                 "temp_min": 56.68,
#                 "temp_max": 66.06,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 1004,
#                 "humidity": 33,
#                 "temp_kf": 5.21
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 1
#             },
#             "wind": {
#                 "speed": 6.73,
#                 "deg": 193,
#                 "gust": 12.71
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-11 03:00:00"
#         },
#         {
#             "dt": 1681192800,
#             "main": {
#                 "temp": 59.74,
#                 "feels_like": 57.52,
#                 "temp_min": 54.23,
#                 "temp_max": 59.74,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 1003,
#                 "humidity": 45,
#                 "temp_kf": 3.06
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ],
#             "clouds": {
#                 "all": 23
#             },
#             "wind": {
#                 "speed": 8.3,
#                 "deg": 212,
#                 "gust": 18.99
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-11 06:00:00"
#         },
#         {
#             "dt": 1681203600,
#             "main": {
#                 "temp": 52.27,
#                 "feels_like": 50.16,
#                 "temp_min": 52.27,
#                 "temp_max": 52.27,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 1003,
#                 "humidity": 63,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ],
#             "clouds": {
#                 "all": 12
#             },
#             "wind": {
#                 "speed": 7.85,
#                 "deg": 230,
#                 "gust": 20.13
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-11 09:00:00"
#         },
#         {
#             "dt": 1681214400,
#             "main": {
#                 "temp": 51.49,
#                 "feels_like": 49.82,
#                 "temp_min": 51.49,
#                 "temp_max": 51.49,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 1003,
#                 "humidity": 74,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ],
#             "clouds": {
#                 "all": 34
#             },
#             "wind": {
#                 "speed": 8.16,
#                 "deg": 225,
#                 "gust": 18.77
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-11 12:00:00"
#         },
#         {
#             "dt": 1681225200,
#             "main": {
#                 "temp": 59.23,
#                 "feels_like": 57.69,
#                 "temp_min": 59.23,
#                 "temp_max": 59.23,
#                 "pressure": 1024,
#                 "sea_level": 1024,
#                 "grnd_level": 1002,
#                 "humidity": 60,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 99
#             },
#             "wind": {
#                 "speed": 9.64,
#                 "deg": 226,
#                 "gust": 15.86
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-11 15:00:00"
#         },
#         {
#             "dt": 1681236000,
#             "main": {
#                 "temp": 66.69,
#                 "feels_like": 65.26,
#                 "temp_min": 66.69,
#                 "temp_max": 66.69,
#                 "pressure": 1022,
#                 "sea_level": 1022,
#                 "grnd_level": 1001,
#                 "humidity": 47,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 99
#             },
#             "wind": {
#                 "speed": 11.23,
#                 "deg": 246,
#                 "gust": 16.35
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-11 18:00:00"
#         },
#         {
#             "dt": 1681246800,
#             "main": {
#                 "temp": 68.27,
#                 "feels_like": 67.1,
#                 "temp_min": 68.27,
#                 "temp_max": 68.27,
#                 "pressure": 1020,
#                 "sea_level": 1020,
#                 "grnd_level": 999,
#                 "humidity": 49,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 12.59,
#                 "deg": 244,
#                 "gust": 17.87
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-11 21:00:00"
#         },
#         {
#             "dt": 1681257600,
#             "main": {
#                 "temp": 65.7,
#                 "feels_like": 64.54,
#                 "temp_min": 65.7,
#                 "temp_max": 65.7,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "grnd_level": 998,
#                 "humidity": 55,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 10.65,
#                 "deg": 232,
#                 "gust": 18.92
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-12 00:00:00"
#         },
#         {
#             "dt": 1681268400,
#             "main": {
#                 "temp": 62.22,
#                 "feels_like": 61.05,
#                 "temp_min": 62.22,
#                 "temp_max": 62.22,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "grnd_level": 998,
#                 "humidity": 62,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 11.88,
#                 "deg": 221,
#                 "gust": 25.37
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-12 03:00:00"
#         },
#         {
#             "dt": 1681279200,
#             "main": {
#                 "temp": 59.56,
#                 "feels_like": 58.37,
#                 "temp_min": 59.56,
#                 "temp_max": 59.56,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "grnd_level": 997,
#                 "humidity": 67,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 11.3,
#                 "deg": 224,
#                 "gust": 27.87
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-12 06:00:00"
#         },
#         {
#             "dt": 1681290000,
#             "main": {
#                 "temp": 57.15,
#                 "feels_like": 55.76,
#                 "temp_min": 57.15,
#                 "temp_max": 57.15,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "grnd_level": 996,
#                 "humidity": 68,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 96
#             },
#             "wind": {
#                 "speed": 11.1,
#                 "deg": 227,
#                 "gust": 28.57
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-12 09:00:00"
#         },
#         {
#             "dt": 1681300800,
#             "main": {
#                 "temp": 55.51,
#                 "feels_like": 54.05,
#                 "temp_min": 55.51,
#                 "temp_max": 55.51,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "grnd_level": 996,
#                 "humidity": 70,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 89
#             },
#             "wind": {
#                 "speed": 11.9,
#                 "deg": 225,
#                 "gust": 28.99
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-12 12:00:00"
#         },
#         {
#             "dt": 1681311600,
#             "main": {
#                 "temp": 62.51,
#                 "feels_like": 61.05,
#                 "temp_min": 62.51,
#                 "temp_max": 62.51,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "grnd_level": 996,
#                 "humidity": 55,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02d"
#                 }
#             ],
#             "clouds": {
#                 "all": 16
#             },
#             "wind": {
#                 "speed": 15.12,
#                 "deg": 232,
#                 "gust": 26.55
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-12 15:00:00"
#         },
#         {
#             "dt": 1681322400,
#             "main": {
#                 "temp": 69.49,
#                 "feels_like": 68.13,
#                 "temp_min": 69.49,
#                 "temp_max": 69.49,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "grnd_level": 994,
#                 "humidity": 42,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02d"
#                 }
#             ],
#             "clouds": {
#                 "all": 13
#             },
#             "wind": {
#                 "speed": 16.73,
#                 "deg": 235,
#                 "gust": 23.73
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-12 18:00:00"
#         },
#         {
#             "dt": 1681333200,
#             "main": {
#                 "temp": 71.56,
#                 "feels_like": 70.21,
#                 "temp_min": 71.56,
#                 "temp_max": 71.56,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "grnd_level": 992,
#                 "humidity": 38,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 4
#             },
#             "wind": {
#                 "speed": 16.33,
#                 "deg": 234,
#                 "gust": 22.79
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-12 21:00:00"
#         },
#         {
#             "dt": 1681344000,
#             "main": {
#                 "temp": 68.09,
#                 "feels_like": 66.72,
#                 "temp_min": 68.09,
#                 "temp_max": 68.09,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "grnd_level": 992,
#                 "humidity": 45,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 3
#             },
#             "wind": {
#                 "speed": 13.42,
#                 "deg": 228,
#                 "gust": 23.33
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-13 00:00:00"
#         },
#         {
#             "dt": 1681354800,
#             "main": {
#                 "temp": 63.48,
#                 "feels_like": 62.17,
#                 "temp_min": 63.48,
#                 "temp_max": 63.48,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "grnd_level": 993,
#                 "humidity": 56,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 3
#             },
#             "wind": {
#                 "speed": 12.66,
#                 "deg": 225,
#                 "gust": 26.26
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-13 03:00:00"
#         },
#         {
#             "dt": 1681365600,
#             "main": {
#                 "temp": 59.22,
#                 "feels_like": 57.88,
#                 "temp_min": 59.22,
#                 "temp_max": 59.22,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "grnd_level": 993,
#                 "humidity": 65,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 2
#             },
#             "wind": {
#                 "speed": 10.96,
#                 "deg": 219,
#                 "gust": 26.8
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-13 06:00:00"
#         },
#         {
#             "dt": 1681376400,
#             "main": {
#                 "temp": 56.37,
#                 "feels_like": 54.81,
#                 "temp_min": 56.37,
#                 "temp_max": 56.37,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "grnd_level": 993,
#                 "humidity": 66,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 7
#             },
#             "wind": {
#                 "speed": 9.93,
#                 "deg": 220,
#                 "gust": 24.07
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-13 09:00:00"
#         },
#         {
#             "dt": 1681387200,
#             "main": {
#                 "temp": 54.75,
#                 "feels_like": 53.26,
#                 "temp_min": 54.75,
#                 "temp_max": 54.75,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "grnd_level": 994,
#                 "humidity": 71,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 9
#             },
#             "wind": {
#                 "speed": 9.26,
#                 "deg": 215,
#                 "gust": 22.06
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-13 12:00:00"
#         },
#         {
#             "dt": 1681398000,
#             "main": {
#                 "temp": 62.56,
#                 "feels_like": 61.02,
#                 "temp_min": 62.56,
#                 "temp_max": 62.56,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "grnd_level": 994,
#                 "humidity": 53,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02d"
#                 }
#             ],
#             "clouds": {
#                 "all": 11
#             },
#             "wind": {
#                 "speed": 11.32,
#                 "deg": 220,
#                 "gust": 18.07
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-13 15:00:00"
#         },
#         {
#             "dt": 1681408800,
#             "main": {
#                 "temp": 69.51,
#                 "feels_like": 68.04,
#                 "temp_min": 69.51,
#                 "temp_max": 69.51,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "grnd_level": 992,
#                 "humidity": 40,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02d"
#                 }
#             ],
#             "clouds": {
#                 "all": 12
#             },
#             "wind": {
#                 "speed": 12.71,
#                 "deg": 217,
#                 "gust": 17.05
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-13 18:00:00"
#         },
#         {
#             "dt": 1681419600,
#             "main": {
#                 "temp": 71.35,
#                 "feels_like": 69.78,
#                 "temp_min": 71.35,
#                 "temp_max": 71.35,
#                 "pressure": 1011,
#                 "sea_level": 1011,
#                 "grnd_level": 991,
#                 "humidity": 34,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 7
#             },
#             "wind": {
#                 "speed": 13.06,
#                 "deg": 211,
#                 "gust": 17.07
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-13 21:00:00"
#         },
#         {
#             "dt": 1681430400,
#             "main": {
#                 "temp": 67.78,
#                 "feels_like": 66.06,
#                 "temp_min": 67.78,
#                 "temp_max": 67.78,
#                 "pressure": 1011,
#                 "sea_level": 1011,
#                 "grnd_level": 991,
#                 "humidity": 38,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 5
#             },
#             "wind": {
#                 "speed": 10.96,
#                 "deg": 202,
#                 "gust": 18.12
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-14 00:00:00"
#         },
#         {
#             "dt": 1681441200,
#             "main": {
#                 "temp": 62.76,
#                 "feels_like": 61.14,
#                 "temp_min": 62.76,
#                 "temp_max": 62.76,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "grnd_level": 991,
#                 "humidity": 51,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 88
#             },
#             "wind": {
#                 "speed": 10.42,
#                 "deg": 193,
#                 "gust": 22.32
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-14 03:00:00"
#         },
#         {
#             "dt": 1681452000,
#             "main": {
#                 "temp": 59.83,
#                 "feels_like": 58.48,
#                 "temp_min": 59.83,
#                 "temp_max": 59.83,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "grnd_level": 991,
#                 "humidity": 63,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 81
#             },
#             "wind": {
#                 "speed": 9.26,
#                 "deg": 196,
#                 "gust": 22.53
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-14 06:00:00"
#         },
#         {
#             "dt": 1681462800,
#             "main": {
#                 "temp": 58.17,
#                 "feels_like": 56.89,
#                 "temp_min": 58.17,
#                 "temp_max": 58.17,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "grnd_level": 991,
#                 "humidity": 68,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 83
#             },
#             "wind": {
#                 "speed": 9.1,
#                 "deg": 193,
#                 "gust": 23.09
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-14 09:00:00"
#         },
#         {
#             "dt": 1681473600,
#             "main": {
#                 "temp": 56.66,
#                 "feels_like": 55.69,
#                 "temp_min": 56.66,
#                 "temp_max": 56.66,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "grnd_level": 991,
#                 "humidity": 78,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 63
#             },
#             "wind": {
#                 "speed": 8.5,
#                 "deg": 189,
#                 "gust": 21
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-14 12:00:00"
#         },
#         {
#             "dt": 1681484400,
#             "main": {
#                 "temp": 62.15,
#                 "feels_like": 61.12,
#                 "temp_min": 62.15,
#                 "temp_max": 62.15,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "grnd_level": 991,
#                 "humidity": 65,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 94
#             },
#             "wind": {
#                 "speed": 9.48,
#                 "deg": 173,
#                 "gust": 14.25
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-14 15:00:00"
#         },
#         {
#             "dt": 1681495200,
#             "main": {
#                 "temp": 68.05,
#                 "feels_like": 67.05,
#                 "temp_min": 68.05,
#                 "temp_max": 68.05,
#                 "pressure": 1010,
#                 "sea_level": 1010,
#                 "grnd_level": 990,
#                 "humidity": 53,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 82
#             },
#             "wind": {
#                 "speed": 12.28,
#                 "deg": 188,
#                 "gust": 17.92
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-14 18:00:00"
#         },
#         {
#             "dt": 1681506000,
#             "main": {
#                 "temp": 67.89,
#                 "feels_like": 67.01,
#                 "temp_min": 67.89,
#                 "temp_max": 67.89,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "grnd_level": 988,
#                 "humidity": 56,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 83
#             },
#             "wind": {
#                 "speed": 13.13,
#                 "deg": 190,
#                 "gust": 18.5
#             },
#             "visibility": 10000,
#             "pop": 0.17,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-14 21:00:00"
#         },
#         {
#             "dt": 1681516800,
#             "main": {
#                 "temp": 64.9,
#                 "feels_like": 64.09,
#                 "temp_min": 64.9,
#                 "temp_max": 64.9,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "grnd_level": 988,
#                 "humidity": 64,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 90
#             },
#             "wind": {
#                 "speed": 12.01,
#                 "deg": 180,
#                 "gust": 19.44
#             },
#             "visibility": 10000,
#             "pop": 0.16,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-15 00:00:00"
#         },
#         {
#             "dt": 1681527600,
#             "main": {
#                 "temp": 61.21,
#                 "feels_like": 60.46,
#                 "temp_min": 61.21,
#                 "temp_max": 61.21,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "grnd_level": 988,
#                 "humidity": 73,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 96
#             },
#             "wind": {
#                 "speed": 10.78,
#                 "deg": 185,
#                 "gust": 20.96
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-15 03:00:00"
#         },
#         {
#             "dt": 1681538400,
#             "main": {
#                 "temp": 58.5,
#                 "feels_like": 57.81,
#                 "temp_min": 58.5,
#                 "temp_max": 58.5,
#                 "pressure": 1008,
#                 "sea_level": 1008,
#                 "grnd_level": 987,
#                 "humidity": 80,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 67
#             },
#             "wind": {
#                 "speed": 10,
#                 "deg": 182,
#                 "gust": 23.09
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-15 06:00:00"
#         },
#         {
#             "dt": 1681549200,
#             "main": {
#                 "temp": 56.75,
#                 "feels_like": 56.26,
#                 "temp_min": 56.75,
#                 "temp_max": 56.75,
#                 "pressure": 1007,
#                 "sea_level": 1007,
#                 "grnd_level": 986,
#                 "humidity": 88,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ],
#             "clouds": {
#                 "all": 18
#             },
#             "wind": {
#                 "speed": 10.02,
#                 "deg": 171,
#                 "gust": 23.87
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-15 09:00:00"
#         },
#         {
#             "dt": 1681560000,
#             "main": {
#                 "temp": 56.14,
#                 "feels_like": 55.72,
#                 "temp_min": 56.14,
#                 "temp_max": 56.14,
#                 "pressure": 1007,
#                 "sea_level": 1007,
#                 "grnd_level": 986,
#                 "humidity": 91,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": {
#                 "all": 46
#             },
#             "wind": {
#                 "speed": 10.38,
#                 "deg": 185,
#                 "gust": 24.72
#             },
#             "visibility": 10000,
#             "pop": 0.41,
#             "rain": {
#                 "3h": 0.59
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-15 12:00:00"
#         },
#         {
#             "dt": 1681570800,
#             "main": {
#                 "temp": 60.57,
#                 "feels_like": 60.13,
#                 "temp_min": 60.57,
#                 "temp_max": 60.57,
#                 "pressure": 1006,
#                 "sea_level": 1006,
#                 "grnd_level": 985,
#                 "humidity": 81,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 13.29,
#                 "deg": 192,
#                 "gust": 23.24
#             },
#             "visibility": 10000,
#             "pop": 0.3,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-15 15:00:00"
#         },
#         {
#             "dt": 1681581600,
#             "main": {
#                 "temp": 62.24,
#                 "feels_like": 61.88,
#                 "temp_min": 62.24,
#                 "temp_max": 62.24,
#                 "pressure": 1005,
#                 "sea_level": 1005,
#                 "grnd_level": 985,
#                 "humidity": 79,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 11.83,
#                 "deg": 209,
#                 "gust": 20.33
#             },
#             "visibility": 10000,
#             "pop": 0.26,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-15 18:00:00"
#         },
#         {
#             "dt": 1681592400,
#             "main": {
#                 "temp": 60.1,
#                 "feels_like": 59.76,
#                 "temp_min": 60.1,
#                 "temp_max": 60.1,
#                 "pressure": 1006,
#                 "sea_level": 1006,
#                 "grnd_level": 985,
#                 "humidity": 84,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 13.22,
#                 "deg": 239,
#                 "gust": 20.42
#             },
#             "visibility": 10000,
#             "pop": 0.86,
#             "rain": {
#                 "3h": 1.41
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-15 21:00:00"
#         }
#     ],
#     "city": {
#         "id": 4928208,
#         "name": "Whiting",
#         "coord": {
#             "lat": 41.7006,
#             "lon": -87.5332
#         },
#         "country": "US",
#         "population": 4997,
#         "timezone": -18000,
#         "sunrise": 1681125494,
#         "sunset": 1681172657
#     }
# }

# %% [markdown]
# ### Subtask 3: Prepare Data for Cleaning
# TODO
# - ✅ Examine the outputted JSON data, and locate the property that holds a **list of weather forecasts**
# - ✅ Save this list of weather forecasts as the variable `forecast_list` below

# %%
forecast_list = five_day_weather['list']
print(forecast_list)
# Out:
# [{'dt': 1681171200, 'main': {'temp': 70.74, 'feels_like': 68.63, 'temp_min': 62.11, 'temp_max': 70.74, 'pressure': 1026, 'sea_level': 1026, 'grnd_level': 1004, 'humidity': 24, 'temp_kf': 4.79}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'clouds': {'all': 0}, 'wind': {'speed': 6.33, 'deg': 221, 'gust': 10.83}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2023-04-11 00:00:00'}, {'dt': 1681182000, 'main': {'temp': 66.06, 'feels_like': 63.91, 'temp_min': 56.68, 'temp_max': 66.06, 'pressure': 1026, 'sea_level': 1026, 'grnd_level': 1004, 'humidity': 33, 'temp_kf': 5.21}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 1}, 'wind': {'speed': 6.73, 'deg': 193, 'gust': 12.71}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-04-11 03:00:00'}, {'dt': 1681192800, 'main': {'temp': 59.74, 'feels_like': 57.52, 'temp_min': 54.23, 'temp_max': 59.74, 'pressure': 1025, 'sea_level': 1025, 'grnd_level': 1003, 'humidity': 45, 'temp_kf': 3.06}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'clouds': {'all': 23}, 'wind': {'speed': 8.3, 'deg': 212, 'gust': 18.99}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-04-11 06:00:00'}, {'dt': 1681203600, 'main': {'temp': 52.27, 'feels_like': 50.16, 'temp_min': 52.27, 'temp_max': 52.27, 'pressure': 1025, 'sea_level': 1025, 'grnd_level': 1003, 'humidity': 63, 'temp_kf': 0}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'clouds': {'all': 12}, 'wind': {'speed': 7.85, 'deg': 230, 'gust': 20.13}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-04-11 09:00:00'}, {'dt': 1681214400, 'main': {'temp': 51.49, 'feels_like': 49.82, 'temp_min': 51.49, 'temp_max': 51.49, 'pressure': 1025, 'sea_level': 1025, 'grnd_level': 1003, 'humidity': 74, 'temp_kf': 0}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'clouds': {'all': 34}, 'wind': {'speed': 8.16, 'deg': 225, 'gust': 18.77}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2023-04-11 12:00:00'}, {'dt': 1681225200, 'main': {'temp': 59.23, 'feels_like': 57.69, 'temp_min': 59.23, 'temp_max': 59.23, 'pressure': 1024, 'sea_level': 1024, 'grnd_level': 1002, 'humidity': 60, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 99}, 'wind': {'speed': 9.64, 'deg': 226, 'gust': 15.86}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2023-04-11 15:00:00'}, {'dt': 1681236000, 'main': {'temp': 66.69, 'feels_like': 65.26, 'temp_min': 66.69, 'temp_max': 66.69, 'pressure': 1022, 'sea_level': 1022, 'grnd_level': 1001, 'humidity': 47, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 99}, 'wind': {'speed': 11.23, 'deg': 246, 'gust': 16.35}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2023-04-11 18:00:00'}, {'dt': 1681246800, 'main': {'temp': 68.27, 'feels_like': 67.1, 'temp_min': 68.27, 'temp_max': 68.27, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 999, 'humidity': 49, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 12.59, 'deg': 244, 'gust': 17.87}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2023-04-11 21:00:00'}, {'dt': 1681257600, 'main': {'temp': 65.7, 'feels_like': 64.54, 'temp_min': 65.7, 'temp_max': 65.7, 'pressure': 1019, 'sea_level': 1019, 'grnd_level': 998, 'humidity': 55, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 10.65, 'deg': 232, 'gust': 18.92}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2023-04-12 00:00:00'}, {'dt': 1681268400, 'm ...

# %% [markdown]
# ### Subtask 4: Data Extraction
# TODO
# - ✅ Loop through each value within `forecast_list`, and perform the following:
#     - ✅ Using square brackets, extract the following properties into their own variable:
#         - Timestamp
#         - Temperature
#         - "Feels Like" Temperature
#         - Wind Speed
#         - Humidity
#     - ✅ Create a **Dictionary** with key:value pairs for each of the above properties
#     - ✅ Append that dictionary to the `data_list` list variable

# %%
data_list = []
for days in forecast_list:
    calendar = datetime.fromtimestamp(days['dt'])
    temp = days['main']['temp']
    real_feel = days['main']['feels_like']
    wind_speed = days['wind']['speed']
    humidity = days['main']['humidity']
    fiveday_weather_dic = {
        'calendar':calendar,
        'Temperature':temp,
        'Real Feel':real_feel,
        'Wind Speed':wind_speed,
        'Humidity':humidity,
    }
    data_list.append(fiveday_weather_dic)

# %% [markdown]
# ### Subtask 5: DataFrame Creation & Munging
# TODO
# - ✅ Using the Pandas DataFrame `.from_records()` method, create a new DataFrame from `data_list`, and save as a variable
# - ✅ Use the appropriate Pandas method to convert the `timestamp` column to DateTime format

# %%
five_day_df = pd.DataFrame.from_records(data_list)
print(five_day_df.head())
# Out:
#              calendar  Temperature  Real Feel  Wind Speed  Humidity
# 0 2023-04-10 19:00:00        70.74      68.63        6.33        24
# 1 2023-04-10 22:00:00        66.06      63.91        6.73        33
# 2 2023-04-11 01:00:00        59.74      57.52        8.30        45
# 3 2023-04-11 04:00:00        52.27      50.16        7.85        63
# 4 2023-04-11 07:00:00        51.49      49.82        8.16        74

# %% [markdown]
# ### Subtask 6: Export Data to JSON
# TODO
# - ✅ Use the appropriate Pandas function to export your DataFrame to **JSON format**
#     - Name your file `forecastdata.json`
#     - Use the orientation **`records`** when outputting
#     - Include the argument **`date_format="iso"`** to ensure all DateTime values are exported correctly!

# %%
five_day_df.to_json('forecastdata.json', orient='records', date_format='iso')

# %% [markdown]
# ### Subtask 7: Data Visualization with Tableau
# TODO
# - ✅ Within Tableau, import your `forecastdata.json` file
# - ✅ Ensure that the `timestamp` column has been converted to Date & Time
# - ✅ Create **two** visualizations exploring trends and patterns in your area's 5-day forecast
# - ✅ Save these visualizations to Tableau Public, then download a copy of the workbook, and include it in your repository folder
